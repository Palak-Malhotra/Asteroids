# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak-Malhotra/Asteroids/blob/main/NASA%20-%20Nearest%20Earth%20Objects/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.max_open_warning': 0})
# %matplotlib inline
import seaborn as sns

# %%
csv_filepath = "/content/neo.csv"

# Read the file into a variable nasa_data
nasa_data = pd.read_csv(csv_filepath, index_col="id")

# %%
nasa_data.head()
# Out:
#                         name  est_diameter_min  est_diameter_max  \
# id
# 2162635  162635 (2000 SS164)          1.198271          2.679415
# 2277475    277475 (2005 WK4)          0.265800          0.594347
# 2512244   512244 (2015 YE18)          0.722030          1.614507
# 3596030          (2012 BV13)          0.096506          0.215794
# 3667127          (2014 GE35)          0.255009          0.570217
#
#          relative_velocity  miss_distance orbiting_body  sentry_object  \
# id
# 2162635       13569.249224   5.483974e+07         Earth          False
# 2277475       73588.726663   6.143813e+07         Earth          False
# 2512244      114258.692129   4.979872e+07         Earth          False
# 3596030       24764.303138   2.543497e+07         Earth          False
# 3667127       42737.733765   4.627557e+07         Earth          False
#
#          absolute_magnitude  hazardous
# id
# 2162635               16.73      False
# 2277475               20.00       True
# 2512244               17.83      False
# 3596030               22.20      False
# 3667127               20.09       True

# %%
# List all Hazardous Objects

list_hazard = nasa_data.loc[nasa_data.hazardous == True]

list_hazard
# Out:
#                         name  est_diameter_min  est_diameter_max  \
# id
# 2277475    277475 (2005 WK4)          0.265800          0.594347
# 3667127          (2014 GE35)          0.255009          0.570217
# 54049873          (2020 OT6)          0.252671          0.564989
# 2506491   506491 (2003 UW29)          0.201630          0.450858
# 3781344            (2017 RV)          0.110804          0.247765
# ...                      ...               ...               ...
# 3776295            (2017 NH)          0.133216          0.297879
# 54235530          (2022 AY1)          0.104847          0.234444
# 2138404   138404 (2000 HA24)          0.356907          0.798068
# 2377732    377732 (2005 XJ8)          1.034082          2.312278
# 3836727            (2018 XR)          0.508809          1.137732
#
#           relative_velocity  miss_distance orbiting_body  sentry_object  \
# id
# 2277475        73588.726663   6.143813e+07         Earth          False
# 3667127        42737.733765   4.627557e+07         Earth          False
# 54049873       58430.697200   3.833750e+07         Earth          False
# 2506491       115899.180498   1.510102e+07         Earth          False
# 3781344        48655.305132   3.279775e+07         Earth          False
# ...                     ...            ...           ...            ...
# 3776295        67595.756852   5.681059e+07         Earth          False
# 54235530       51149.696785   5.450002e+07         Earth          False
# 2138404        33008.617883   7.189835e+07         Earth          False
# 2377732        53362.798148   4.756627e+07         Earth          False
# 3836727        71465.448580   8.894222e+06         Earth          False
#
#           absolute_magnitude  hazardous
# id
# 2277475                20.00       True
# 3667127                20.09       True
# 54049873               20.11       True
# 2506491                20.60       True
# 3781344                21.90       True
# ...                      ...        ...
# 3776295                21.50       True
# 54235530               22.02       True
# 2138404                19.36       True
# 2377732                17.05       True
# 3836727                18.59       True
#
# [8840 rows x 9 columns]

# %%
# Stats on Relative Velocities of the objects

nasa_data.relative_velocity.describe()
# Out:
# count     90836.000000
# mean      48066.918918
# std       25293.296961
# min         203.346433
# 25%       28619.020645
# 50%       44190.117890
# 75%       62923.604633
# max      236990.128088
# Name: relative_velocity, dtype: float64

# %%
# Stats on Relative Velocities of the Hazardous Objects

list_hazard.relative_velocity.describe()
# Out:
# count      8840.000000
# mean      62794.337025
# std       27175.110049
# min        5908.291826
# 25%       43017.810183
# 50%       58658.010358
# 75%       78785.820511
# max      193386.975218
# Name: relative_velocity, dtype: float64

# %%
# Store Top 25 Fastest Hazardous Near-Earth Objects in a separate DataFrame
top_fastest_hazards = list_hazard.sort_values(by='relative_velocity', ascending=False).iloc[:25]

top_fastest_hazards
# Out:
#                                    name  est_diameter_min  est_diameter_max  \
# id
# 3824084                      (2018 JD2)          0.441118          0.986370
# 3655362                       (2013 YC)          0.148100          0.331162
# 3670721                     (2014 JO25)          0.732074          1.636967
# 2374158                374158 (2004 UL)          0.485909          1.086526
# 3724392                     (2015 OC22)          0.265800          0.594347
# 2425755               425755 (2011 CP4)          0.152952          0.342011
# 3775155                     (2017 KN34)          0.303777          0.679266
# 3729835                    (2015 TB145)          0.260949          0.583499
# 2386454                386454 (2008 XM)          0.265800          0.594347
# 3842777                      (2019 LZ1)          0.291444          0.651688
# 3005973                       (1995 CR)          0.116026          0.259442
# 2523630                523630 (2009 OG)          1.529519          3.420109
# 2471926   471926 Jormungandr (2013 KN6)          0.520661          1.164233
# 3005973                       (1995 CR)          0.116026          0.259442
# 3712625                    (2015 DC200)          0.211132          0.472106
# 3755203                     (2016 NT22)          0.334622          0.748238
# 2242643               242643 (2005 NZ6)          0.888290          1.986278
# 3843858                      (2019 RU3)          0.649464          1.452245
# 54203006                     (2021 SZ4)          0.215058          0.480884
# 2386454                386454 (2008 XM)          0.265800          0.594347
# 3117435                     (2002 EV11)          0.265800          0.594347
# 3670721                     (2014 JO25)          0.732074          1.636967
# 3707694                    (2015 BL311)          0.167708          0.375008
# 2466130              466130 (2012 FZ23)          0.595052          1.330577
# 2504034             504034 (2005 UJ159)          0.802703          1.794899
#
#           relative_velocity  miss_distance orbiting_body  sentry_object  \
# id
# 3824084       193386.975218   7.466753e+07         Earth          False
# 3655362       191176.458196   6.921508e+07         Earth          False
# 3670721       175424.757666   7.377460e+07         Earth          False
# 2374158       174875.355324   5.934208e+07         Earth          False
# 3724392       172227.337190   6.859516e+07         Earth          False
# 2425755       170893.025786   7.391006e+07         Earth          False
# 3775155       167111.453695   6.472028e+07         Earth          False
# 3729835       167039.877907   5.945226e+07         Earth          False
# 2386454       166503.871663   5.413871e+07         Earth          False
# 3842777       164625.414716   5.020979e+07         Earth          False
# 3005973       164471.199839   6.800032e+07         Earth          False
# 2523630       163954.905191   5.471484e+07         Earth          False
# 2471926       163285.783779   6.731215e+07         Earth          False
# 3005973       163002.677578   6.643994e+07         Earth          False
# 3712625       160718.858674   6.007499e+07         Earth          False
# 3755203       160576.891427   6.272840e+07         Earth          False
# 2242643       158623.718271   6.423605e+07         Earth          False
# 3843858       158556.006826   7.041187e+07         Earth          False
# 54203006      157827.454183   6.859230e+07         Earth          False
# 2386454       156817.108168   4.489089e+07         Earth          False
# 3117435       156347.152422   5.199938e+07         Earth          False
# 3670721       156117.422890   4.920260e+07         Earth          False
# 3707694       156114.533094   6.868383e+07         Earth          False
# 2466130       155957.379719   6.271890e+07         Earth          False
# 2504034       154743.835811   7.179462e+07         Earth          False
#
#           absolute_magnitude  hazardous
# id
# 3824084                18.90       True
# 3655362                21.27       True
# 3670721                17.80       True
# 2374158                18.69       True
# 3724392                20.00       True
# 2425755                21.20       True
# 3775155                19.71       True
# 3729835                20.04       True
# 2386454                20.00       True
# 3842777                19.80       True
# 3005973                21.80       True
# 2523630                16.20       True
# 2471926                18.54       True
# 3005973                21.80       True
# 3712625                20.50       True
# 3755203                19.50       True
# 2242643                17.38       True
# 3843858                18.06       True
# 54203006               20.46       True
# 2386454                20.00       True
# 3117435                20.00       True
# 3670721                17.80       True
# 3707694                21.00       True
# 2466130                18.25       True
# 2504034                17.60       True

# %%
top_fastest_hazards.iloc[0] # Display details about the fastest hazardous object
# Out:
# name                       (2018 JD2)
# est_diameter_min             0.441118
# est_diameter_max              0.98637
# relative_velocity       193386.975218
# miss_distance         74667534.229867
# orbiting_body                   Earth
# sentry_object                   False
# absolute_magnitude               18.9
# hazardous                        True
# Name: 3824084, dtype: object

# %%
list_hazard.sort_values(by='miss_distance').iloc[:1]
# Out:
#                 name  est_diameter_min  est_diameter_max  relative_velocity  \
# id
# 3789399  (2017 VW13)          0.192555          0.430566       40792.770407
#
#          miss_distance orbiting_body  sentry_object  absolute_magnitude  \
# id
# 3789399  143272.707499         Earth          False                20.7
#
#          hazardous
# id
# 3789399       True

# %% [markdown]
# #Visualizing the data

# %%
sns.pairplot(
    data = nasa_data[['est_diameter_min','est_diameter_max','relative_velocity','miss_distance','absolute_magnitude','hazardous']],
    hue='hazardous'
)

# %%
# Plot a bar graph to demonstrate Luminosity of Fastest Near-Earth Objects

plt.figure()
plt.title("Luminosity of Top 25 Fastest Hazardous Space Objects close to the Earth")
sns.barplot(x = top_fastest_hazards.absolute_magnitude, y = top_fastest_hazards.name)
plt.ylabel("")
plt.xlabel("Luminosity (Absolute Magnitude)")
# Out:
# Text(0.5, 0, 'Luminosity (Absolute Magnitude)')

# %%
num_vals = ['est_diameter_max','relative_velocity','miss_distance','absolute_magnitude']

for p in num_vals:
    for q in num_vals:
        if p != q:
            plt.figure()
            sns.lmplot(
                x = p,
                y = q,
                hue = 'hazardous',
                data = nasa_data
            )

# %%
interest_data = [
    ['absolute_magnitude','relative_velocity'],
    ['absolute_magnitude','miss_distance'],
    ['est_diameter_max','relative_velocity']
]

for i in interest_data:
    plt.figure()
    sns.set_style("whitegrid")
    sns.jointplot(
        x=nasa_data[i[0]],
        y=nasa_data[i[1]],
        data = nasa_data,
        hue = 'hazardous',
        kind="kde"
)

# %%
sns.histplot(data = nasa_data, x = 'absolute_magnitude', hue='hazardous')
# Out:
# <Axes: xlabel='absolute_magnitude', ylabel='Count'>

# %%
plt.figure(figsize=(10,4))
sns.stripplot(
    data = nasa_data,
    x = "absolute_magnitude",
    y = "hazardous",
    hue = "hazardous",
    orient = 'h',
    legend=False
)
plt.grid()
